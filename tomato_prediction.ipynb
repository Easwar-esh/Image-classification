# %%
from google.colab import drive
import os

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/08/beginners-guide-to-convolutional-neural-network-with-implementation-in-python/#:~:text=Convolutional%20Neural%20Network%20is%20a,based%20on%20the%20learned%20features.

# %%
#drive connection
drive.mount('/content/drive')
os.getcwd()
os.chdir('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_path= "/content/drive/MyDrive/train"
val="/content/drive/MyDrive/val"

# %%
#importing the required libraries
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %%
#loading data
(X_train,y_train) , (X_test,y_test)=mnist.load_data()
#reshaping data
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], X_train.shape[2], 1))
X_test = X_test.reshape((X_test.shape[0],X_test.shape[1],X_test.shape[2],1)) 
#checking the shape after reshaping
print(X_train.shape)
print(X_test.shape)
#normalizing the pixel values
X_train=X_train/255
X_test=X_test/255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
#defining model
model=Sequential()
#adding convolution layer
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)))
#adding pooling layer
model.add(MaxPool2D(2,2))
#adding fully connected layer
model.add(Flatten())
model.add(Dense(100,activation='relu'))
#adding output layer
model.add(Dense(10,activation='softmax'))
#compiling the model
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
#fitting the model
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 16s 3ms/step - loss: 0.1517 - accuracy: 0.9542
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0520 - accuracy: 0.9841
# Epoch 3/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0336 - accuracy: 0.9900
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0230 - accuracy: 0.9926
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0155 - accuracy: 0.9948
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0099 - accuracy: 0.9971
# Epoch 7/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0077 - accuracy: 0.9974
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0065 - accuracy: 0.9980
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0066 - accuracy: 0.9977
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0036 - accuracy: 0.9988

# %%
import pandas as pd
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

DATASET=train_path
DATASET2=val

CATEGORIES=["Tomato___Bacterial_spot","Tomato___Early_blight","Tomato___healthy","Tomato___Late_blight","Tomato___Leaf_Mold","Tomato___Septoria_leaf_spot","Tomato___Spider_mites Two-spotted_spider_mite","Tomato___Target_Spot","Tomato___Tomato_mosaic_virus","Tomato___Tomato_Yellow_Leaf_Curl_Virus"]
        
train_data=[]

for category in CATEGORIES:
        label=CATEGORIES.index(category)
        path=os.path.join(DATASET,category)
        for img_file in os.listdir(path):
            img=cv.imread(os.path.join(path,img_file),1)
            img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
            img=cv.resize(img,(64,64))            
            train_data.append([img,label])
            
test_data=[]

for category in CATEGORIES:
        label=CATEGORIES.index(category)
        path=os.path.join(DATASET2,category)
        for img_file in os.listdir(path):
            img=cv.imread(os.path.join(path,img_file),1)
            img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
            img=cv.resize(img,(64,64))
            test_data.append([img,label])
            
print(len(train_data))
print(len(test_data))

import random

random.shuffle(train_data)
random.shuffle(test_data)

for lbl in train_data[:10]:
    print(lbl[1])
    
X_train=[]
y_train=[]

for features,label in train_data:
    X_train.append(features)
    y_train.append(label)

Y=[]
for i in y_train:
    if i==0:
        Y.append("BACTERIAL SPOT")
    elif i==1:
        Y.append("EARLY BLIGHT")
    elif i==2:
        Y.append("HEALTHY")
    elif i==3:
        Y.append("LATE BLIGHT")
    elif i==4:
        Y.append("LEAF MOLD")
    elif i==5:
        Y.append("SEPTORIA LEAF SPOT")
    elif i==6:
        Y.append("SPIDER MITE")
    elif i==7:
        Y.append("TARGET SPOT")
    elif i==8:
        Y.append("MOSAIC VIRUS")
    else:
        Y.append("YELLOW LEAF CURL VIRUS")

len(X_train),len(y_train)

X_test=[]
y_test=[]

for features,label in test_data:
    X_test.append(features)
    y_test.append(label)
    
Z=[]
for i in y_test:
    if i==0:
        Z.append("BACTERIAL SPOT")
    elif i==1:
        Z.append("EARLY BLIGHT")
    elif i==2:
        Z.append("HEALTHY")
    elif i==3:
        Z.append("LATE BLIGHT")
    elif i==4:
        Z.append("LEAF MOLD")
    elif i==5:
        Z.append("SEPTORIA LEAF SPOT")
    elif i==6:
        Z.append("SPIDER MITE")
    elif i==7:
        Z.append("TARGET SPOT")
    elif i==8:
        Z.append("MOSAIC VIRUS")
    else:
        Z.append("YELLOW LEAF CURL VIRUS")

len(X_test),len(y_test)

X_train=np.array(X_train).reshape(-1,64,64,3)
X_train=X_train/255.0
X_train.shape

X_test=np.array(X_test).reshape(-1,64,64,3)
X_test=X_test/255.0
X_test.shape

order=['BACTERIAL SPOT','EARLY BLIGHT','HEALTHY','LATE BLIGHT','LEAF MOLD','SEPTORIA LEAF SPOT','SPIDER MITE','TARGET SPOT','MOSAIC VIRUS','YELLOW LEAF CURL VIRUS']

ax=sns.countplot(Y, order=order)
ax.set_xlabel("Leaf Diseases")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
ax.set_ylabel("Image Count")

ax=sns.countplot(Z, order=order)
ax.set_xlabel("Leaf Diseases")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
ax.set_ylabel("Image Count")

from tensorflow.keras.utils import to_categorical

one_hot_train=to_categorical(y_train)
one_hot_train

one_hot_test=to_categorical(y_test)
one_hot_test

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,Dense,Flatten,MaxPooling2D,Dropout

classifier=Sequential()

classifier.add(Conv2D(32,(3,3), input_shape=(64,64,3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Dropout(0.2))

classifier.add(Conv2D(64,(3,3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Dropout(0.2))

classifier.add(Conv2D(128,(3,3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Dropout(0.4))

classifier.add(Flatten())

classifier.add(Dense(activation='relu', units=64))
classifier.add(Dense(activation='relu', units=128))
classifier.add(Dense(activation='relu', units=64))
classifier.add(Dense(activation='softmax', units=10))

classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

classifier.summary()

hist=classifier.fit(X_train,one_hot_train,epochs=75,batch_size=128,validation_split=0.2)

test_loss,test_acc=classifier.evaluate(X_test,one_hot_test)
test_loss,test_acc

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Classifier Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper right')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Classifier Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper left')
plt.show()

y_pred=(classifier.predict(X_test) > 0.5).astype("int32")
y_pred

y_prob=(classifier.predict(X_test) > 0.5).astype("int32")
y_prob

from sklearn.metrics import roc_curve, auc

fpr = {}
tpr = {}
thresh ={}
roc_auc={}

n_class = 10

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob[:,i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])
      
plt.plot(fpr[0], tpr[0], color='orange',label='Bacterial Spot AUC = %0.3f' % roc_auc[0])
plt.plot(fpr[1], tpr[1], color='green',label='Early Blight AUC = %0.3f' % roc_auc[1])
plt.plot(fpr[2], tpr[2], color='blue',label='Healthy AUC = %0.3f' % roc_auc[2])
plt.plot(fpr[3], tpr[3], color='red',label='Late Blight AUC = %0.3f' % roc_auc[3])
plt.plot(fpr[4], tpr[4], color='pink',label='Leaf Mold AUC = %0.3f' % roc_auc[4])
plt.plot(fpr[5], tpr[5], color='purple',label='Septoria Leaf Spot AUC = %0.3f' % roc_auc[5])
plt.plot(fpr[6], tpr[6], color='brown',label='Spider Mites AUC = %0.3f' % roc_auc[6])
plt.plot(fpr[7], tpr[7], color='cyan',label='Target Spot AUC = %0.3f' % roc_auc[7])
plt.plot(fpr[8], tpr[8], color='yellow',label='Mosaic Virus AUC = %0.3f' % roc_auc[8])
plt.plot(fpr[9], tpr[9], color='black',label='Yellow Leaf Curl Virus AUC = %0.3f' % roc_auc[9])
plt.title('Tomato Leaves Diseases ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(y_test.argmax(axis=1),y_pred))
cm=confusion_matrix(y_test.argmax(axis=1),y_pred)
# Out:
# 10020
# 1000
# 3
# 3
# 3
# 2
# 2
# 5
# 7
# 4
# 5
# 9
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 62, 62, 32)        896
#
#  max_pooling2d_4 (MaxPooling  (None, 31, 31, 32)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 31, 31, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten_2 (Flatten)         (None, 4608)              0
#
#  dense_6 (Dense)             (None, 64)                294976
#
#  dense_7 (Dense)             (None, 128)               8320
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 405,450
# Trainable params: 405,450
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/75
# 63/63 [==============================] - 2s 26ms/step - loss: 2.1497 - accuracy: 0.1972 - val_loss: 1.8883 - val_accuracy: 0.3458
# Epoch 2/75
# 63/63 [==============================] - 1s 21ms/step - loss: 1.4868 - accuracy: 0.4764 - val_loss: 1.3393 - val_accuracy: 0.5529
# Epoch 3/75
# 63/63 [==============================] - 1s 21ms/step - loss: 1.1192 - accuracy: 0.6154 - val_loss: 0.9318 - val_accuracy: 0.6926
# Epoch 4/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.8427 - accuracy: 0.7053 - val_loss: 0.8399 - val_accuracy: 0.7096
# Epoch 5/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.6893 - accuracy: 0.7647 - val_loss: 0.6815 - val_accuracy: 0.7695
# Epoch 6/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.6245 - accuracy: 0.7829 - val_loss: 0.6360 - val_accuracy: 0.7899
# Epoch 7/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.5419 - accuracy: 0.8172 - val_loss: 0.5582 - val_accuracy: 0.8129
# Epoch 8/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.4850 - accuracy: 0.8322 - val_loss: 0.5820 - val_accuracy: 0.7944
# Epoch 9/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.4667 - accuracy: 0.8391 - val_loss: 0.4916 - val_accuracy: 0.8283
# Epoch 10/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.4200 - accuracy: 0.8518 - val_loss: 0.4344 - val_accuracy: 0.8473
# Epoch 11/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.3806 - accuracy: 0.8693 - val_loss: 0.4355 - val_accuracy: 0.8528
# Epoch 12/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.3618 - accuracy: 0.8721 - val_loss: 0.4259 - val_accuracy: 0.8473
# Epoch 13/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.3473 - accuracy: 0.8776 - val_loss: 0.4052 - val_accuracy: 0.8518
# Epoch 14/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.3683 - accuracy: 0.8733 - val_loss: 0.3796 - val_accuracy: 0.8688
# Epoch 15/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.3057 - accuracy: 0.8947 - val_loss: 0.3351 - val_accuracy: 0.8832
# Epoch 16/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.2978 - accuracy: 0.8948 - val_loss: 0.3701 - val_accuracy: 0.8723
# Epoch 17/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.2775 - accuracy: 0.9061 - val_loss: 0.3480 - val_accuracy: 0.8767
# Epoch 18/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.2514 - accuracy: 0.9104 - val_loss: 0.3386 - val_accuracy: 0.8772
# Epoch 19/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.2677 - accuracy: 0.9078 - val_loss: 0.3640 - val_accuracy: 0.8668
# Epoch 20/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.2216 - accuracy: 0.9215 - val_loss: 0.3172 - val_accuracy: 0.8892
# Epoch 21/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.2016 - accuracy: 0.9290 - val_loss: 0.3968 - val_accuracy: 0.8588
# Epoch 22/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.2261 - accuracy: 0.9182 - val_loss: 0.3629 - val_accuracy: 0.8738
# Epoch 23/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.2108 - accuracy: 0.9255 - val_loss: 0.3298 - val_accuracy: 0.8847
# Epoch 24/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1777 - accuracy: 0.9371 - val_loss: 0.3198 - val_accuracy: 0.8812
# Epoch 25/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1973 - accuracy: 0.9299 - val_loss: 0.2565 - val_accuracy: 0.9037
# Epoch 26/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1657 - accuracy: 0.9407 - val_loss: 0.2826 - val_accuracy: 0.9067
# Epoch 27/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1845 - accuracy: 0.9350 - val_loss: 0.2557 - val_accuracy: 0.9142
# Epoch 28/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1315 - accuracy: 0.9553 - val_loss: 0.2361 - val_accuracy: 0.9192
# Epoch 29/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1371 - accuracy: 0.9520 - val_loss: 0.4000 - val_accuracy: 0.8743
# Epoch 30/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1607 - accuracy: 0.9430 - val_loss: 0.3833 - val_accuracy: 0.8767
# Epoch 31/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1497 - accuracy: 0.9460 - val_loss: 0.2718 - val_accuracy: 0.9112
# Epoch 32/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1428 - accuracy: 0.9485 - val_loss: 0.2465 - val_accuracy: 0.9192
# Epoch 33/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1072 - accuracy: 0.9633 - val_loss: 0.2456 - val_accuracy: 0.9187
# Epoch 34/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1195 - accuracy: 0.9591 - val_loss: 0.2948 - val_accuracy: 0.8952
# Epoch 35/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1098 - accuracy: 0.9631 - val_loss: 0.2845 - val_accuracy: 0.9087
# Epoch 36/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1310 - accuracy: 0.9538 - val_loss: 0.2842 - val_accuracy: 0.9057
# Epoch 37/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1164 - accuracy: 0.9583 - val_loss: 0.2342 - val_accuracy: 0.9261
# Epoch 38/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1037 - accuracy: 0.9634 - val_loss: 0.2442 - val_accuracy: 0.9182
# Epoch 39/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0922 - accuracy: 0.9659 - val_loss: 0.2844 - val_accuracy: 0.9152
# Epoch 40/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0844 - accuracy: 0.9691 - val_loss: 0.2594 - val_accuracy: 0.9247
# Epoch 41/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0899 - accuracy: 0.9659 - val_loss: 0.2504 - val_accuracy: 0.9256
# Epoch 42/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0975 - accuracy: 0.9662 - val_loss: 0.2703 - val_accuracy: 0.9172
# Epoch 43/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.1140 - accuracy: 0.9620 - val_loss: 0.2439 - val_accuracy: 0.9197
# Epoch 44/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0972 - accuracy: 0.9679 - val_loss: 0.2502 - val_accuracy: 0.9172
# Epoch 45/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0814 - accuracy: 0.9709 - val_loss: 0.2246 - val_accuracy: 0.9311
# Epoch 46/75
# 63/63 [==============================] - 1s 22ms/step - loss: 0.0696 - accuracy: 0.9757 - val_loss: 0.2685 - val_accuracy: 0.9276
# Epoch 47/75
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0716 - accuracy: 0.9737 - val_loss: 0.2571 - val_accuracy: 0.9172
# Epoch 48/75
# 63/63 [==============================] - 1s 23ms/step - loss: 0.0620 - accuracy: 0.9782 - val_loss: 0.2507 - val_accuracy: 0.9286
# Epoch 49/75
# 63/63 [==============================] - 1s 22ms/step - loss: 0.0767 - accuracy: 0.9732 - val_loss: 0.2239 - val_accuracy: 0.9321
# Epoch 50/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0662 - accuracy: 0.9768 - val_loss: 0.2886 - val_accuracy: 0.9192
# Epoch 51/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0655 - accuracy: 0.9768 - val_loss: 0.2540 - val_accuracy: 0.9217
# Epoch 52/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0682 - accuracy: 0.9764 - val_loss: 0.2698 - val_accuracy: 0.9207
# Epoch 53/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0754 - accuracy: 0.9722 - val_loss: 0.2711 - val_accuracy: 0.9202
# Epoch 54/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0463 - accuracy: 0.9840 - val_loss: 0.2531 - val_accuracy: 0.9217
# Epoch 55/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0777 - accuracy: 0.9719 - val_loss: 0.2975 - val_accuracy: 0.9087
# Epoch 56/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0639 - accuracy: 0.9764 - val_loss: 0.2843 - val_accuracy: 0.9172
# Epoch 57/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0629 - accuracy: 0.9762 - val_loss: 0.3025 - val_accuracy: 0.9107
# Epoch 58/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0934 - accuracy: 0.9677 - val_loss: 0.2470 - val_accuracy: 0.9261
# Epoch 59/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0922 - accuracy: 0.9669 - val_loss: 0.3002 - val_accuracy: 0.8987
# Epoch 60/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0547 - accuracy: 0.9813 - val_loss: 0.2735 - val_accuracy: 0.9217
# Epoch 61/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0409 - accuracy: 0.9864 - val_loss: 0.2636 - val_accuracy: 0.9286
# Epoch 62/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0439 - accuracy: 0.9828 - val_loss: 0.2281 - val_accuracy: 0.9326
# Epoch 63/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0579 - accuracy: 0.9792 - val_loss: 0.2801 - val_accuracy: 0.9237
# Epoch 64/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0780 - accuracy: 0.9739 - val_loss: 0.2474 - val_accuracy: 0.9271
# Epoch 65/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0496 - accuracy: 0.9835 - val_loss: 0.2107 - val_accuracy: 0.9391
# Epoch 66/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0522 - accuracy: 0.9813 - val_loss: 0.2582 - val_accuracy: 0.9296
# Epoch 67/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0445 - accuracy: 0.9833 - val_loss: 0.2474 - val_accuracy: 0.9336
# Epoch 68/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0419 - accuracy: 0.9854 - val_loss: 0.2270 - val_accuracy: 0.9391
# Epoch 69/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0441 - accuracy: 0.9842 - val_loss: 0.2956 - val_accuracy: 0.9147
# Epoch 70/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0970 - accuracy: 0.9671 - val_loss: 0.3896 - val_accuracy: 0.8957
# Epoch 71/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0658 - accuracy: 0.9779 - val_loss: 0.2524 - val_accuracy: 0.9331
# Epoch 72/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0525 - accuracy: 0.9817 - val_loss: 0.2771 - val_accuracy: 0.9217
# Epoch 73/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0488 - accuracy: 0.9835 - val_loss: 0.2436 - val_accuracy: 0.9346
# Epoch 74/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0423 - accuracy: 0.9844 - val_loss: 0.3019 - val_accuracy: 0.9227
# Epoch 75/75
# 63/63 [==============================] - 1s 21ms/step - loss: 0.0432 - accuracy: 0.9844 - val_loss: 0.2452 - val_accuracy: 0.9336
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3667 - accuracy: 0.9160
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-4c2c25efffa7> in <module>()
#     221 from sklearn.metrics import confusion_matrix
#     222
# --> 223 sns.heatmap(confusion_matrix(y_test.argmax(axis=1),y_pred))
#     224 cm=confusion_matrix(y_test.argmax(axis=1),y_pred)
#
# AttributeError: 'list' object has no attribute 'argmax'

# %%
ax=sns.countplot(Y, order=order)
ax.set_xlabel("Leaf Diseases")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
ax.set_ylabel("Image Count")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Image Count')

# %%
ax=sns.countplot(Z, order=order)
ax.set_xlabel("Leaf Diseases")
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
ax.set_ylabel("Image Count")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Image Count')
